# %%
# %load_ext autoreload
# %autoreload 2

# Import plot functions from parent directory
import sys
sys.path.append('..')
from progress_log_visualization import plot_progress_curve, load_progress_log

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
#plt.rcParams['figure.facecolor'] = 'white'
plt.rc('figure', facecolor='w')

# %% [markdown]
# # Results on Reach-Line

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 12), sharey='col')
data = load_progress_log('../../output/metaworld-ml1-reach-line/2022_01_20_03_00_53')
plot_progress_curve(data, 'train_avg_reward', y_shaded='minmax', fig_ax=(fig, ax[0, 0]))
plot_progress_curve(data, 'train_eval_success_rate', fig_ax=(fig, ax[0, 1]))
plot_progress_curve(data, 'test_avg_reward', y_shaded='minmax', fig_ax=(fig, ax[1, 0]))
plot_progress_curve(data, 'test_eval_success_rate', fig_ax=(fig, ax[1, 1]))

fig.suptitle('ML1 reach-line (unobservable)', size=20)
fig.tight_layout()

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 12), sharey='col')
data = load_progress_log('../../output/metaworld-ml1-reach-line-observable/2022_01_20_03_03_17')
plot_progress_curve(data, 'train_avg_reward', y_shaded='minmax', fig_ax=(fig, ax[0, 0]))
plot_progress_curve(data, 'train_eval_success_rate', fig_ax=(fig, ax[0, 1]))
plot_progress_curve(data, 'test_avg_reward', y_shaded='minmax', fig_ax=(fig, ax[1, 0]))
plot_progress_curve(data, 'test_eval_success_rate', fig_ax=(fig, ax[1, 1]))

fig.suptitle('ML1 reach-line (TARGETS GIVEN)', size=20)
fig.tight_layout()

# %% [markdown]
# # Results on Reach-Line Action-Restricted

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 12), sharey='col')
data = load_progress_log('../../output/metaworld-ml1-reach-line-action-restricted/2022_01_20_03_02_09')
plot_progress_curve(data, 'train_avg_reward', y_shaded='minmax', fig_ax=(fig, ax[0, 0]))
plot_progress_curve(data, 'train_eval_success_rate', fig_ax=(fig, ax[0, 1]))
plot_progress_curve(data, 'test_avg_reward', y_shaded='minmax', fig_ax=(fig, ax[1, 0]))
plot_progress_curve(data, 'test_eval_success_rate', fig_ax=(fig, ax[1, 1]))

fig.suptitle('ML1 reach-line action-restricted (unobservable)', size=20)
fig.tight_layout()

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 12), sharey='col')
data = load_progress_log('../../output/metaworld-ml1-reach-line-action-restricted/2022_01_20_03_05_59')
plot_progress_curve(data, 'train_avg_reward', y_shaded='minmax', fig_ax=(fig, ax[0, 0]))
plot_progress_curve(data, 'train_eval_success_rate', fig_ax=(fig, ax[0, 1]))
plot_progress_curve(data, 'test_avg_reward', y_shaded='minmax', fig_ax=(fig, ax[1, 0]))
plot_progress_curve(data, 'test_eval_success_rate', fig_ax=(fig, ax[1, 1]))

fig.suptitle('ML1 reach-line action-restricted (unobservable; GMM)', size=20)
fig.tight_layout()

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 12), sharey='col')
data = load_progress_log('../../output/metaworld-ml1-reach-line-action-restricted-observable/2022_01_19_17_07_05')
plot_progress_curve(data, 'train_avg_reward', y_shaded='minmax', fig_ax=(fig, ax[0, 0]))
plot_progress_curve(data, 'train_eval_success_rate', fig_ax=(fig, ax[0, 1]))
plot_progress_curve(data, 'test_avg_reward', y_shaded='minmax', fig_ax=(fig, ax[1, 0]))
plot_progress_curve(data, 'test_eval_success_rate', fig_ax=(fig, ax[1, 1]))

fig.suptitle('ML1 reach-line action-restricted (TARGETS GIVEN)', size=20)
fig.tight_layout()

# %% [markdown]
# # For comparison: Results on standard ML1-reach

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 12), sharey='col')
data = load_progress_log('../../output/metaworld-ml1-reach/2022_01_10_04_00_17')
plot_progress_curve(data, 'train_avg_reward', y_shaded='minmax', fig_ax=(fig, ax[0, 0]))
plot_progress_curve(data, 'train_eval_success_rate', fig_ax=(fig, ax[0, 1]))
plot_progress_curve(data, 'test_avg_reward', y_shaded='minmax', fig_ax=(fig, ax[1, 0]))
plot_progress_curve(data, 'test_eval_success_rate', fig_ax=(fig, ax[1, 1]))

fig.suptitle('Standard ML1 reach (unobservable)', size=20)
fig.tight_layout()

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 12), sharey='col')
data = load_progress_log('../../output/metaworld-ml1-reach-observable/2021_12_23_12_53_08')
plot_progress_curve(data, 'train_avg_reward', y_shaded='minmax', fig_ax=(fig, ax[0, 0]))
plot_progress_curve(data, 'train_eval_success_rate', fig_ax=(fig, ax[0, 1]))
plot_progress_curve(data, 'test_avg_reward', y_shaded='minmax', fig_ax=(fig, ax[1, 0]))
plot_progress_curve(data, 'test_eval_success_rate', fig_ax=(fig, ax[1, 1]))

fig.suptitle('Standard ML1 reach (TARGETS GIVEN)', size=20)
fig.tight_layout()
