# %%
# %load_ext autoreload
# %autoreload 2

# Import plot functions from parent directory
import sys
sys.path.append('..')
sys.path.append('../..')
from plot_training_progress import plot_progress_curve, load_progress_log
from analysis_runner import prepare_variant_file, analysis, deep_update_dict

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
#plt.rcParams['figure.facecolor'] = 'white'
plt.rc('figure', facecolor='w')
plt.rcParams.update({'font.size':20})

# %%
import copy

base_config = dict(
    path_to_weights = None,
    save_dir = None,
    showcase_itr = None,
    util_params=dict(
        base_log_dir='.temp',  # name of output directory
        use_gpu=True,  # set True if GPU available and should be used
        use_multiprocessing=False,  # set True if data collection should be parallelized across CPUs
        gpu_id=0,  # number of GPU if machine with multiple GPUs
    ),
    analysis_params=dict(
        train_example_cases=[],
        example_cases=[6, 7, 8, 9, 24, ],  # CONFIGURE! choose an array of test tasks
        single_episode_plots=[],
        multiple_episode_plots=[['time_vs_specification', 'time_vs_rewards', 'time_vs_pos_const_specification'],],
        plot_encoding=False,  # CONFIGURE! If True: plots encoding for showcase_itr
        log_and_plot_progress=False,
        save=False,  # CONFIGURE! If True: plots of following options will be saved to the experiment folder
        show=False,
        manipulate_time_steps=False,  # CONFIGURE! If True: uses time_steps different recent context, as specified below
        manipulate_change_trigger=False,  # CONFIGURE! for non-stationary envs: change the trigger for task changes
        manipulate_max_path_length=False,  # CONFIGURE! change max_path_length to value specified below
        manipulate_test_task_number=False,  # CONFIGURE! change test_task_number to value specified below
        visualize_run=False,  # CONFIGURE! If True: learned policy of the showcase_itr will be played on example_case
    ),
    env_params=dict(),
    algo_params=dict(
        use_fixed_seeding=True,
        seed=0,
    ),
    reconstruction_params=dict()
)

# %% [markdown]
# # Baseline Encoder

# %%
cheetah_target_config = copy.deepcopy(base_config)
cheetah_target_config = deep_update_dict(
    dict(
        path_to_weights='../../output/cheetah-stationary-target-normalizedReward-allT/2022_02_13_00_46_57',
        showcase_itr=500,
        analysis_params=dict(
            example_cases=[6, 7, 8, 9, 24, ],  # CONFIGURE! choose an array of test tasks
            multiple_episode_plots=[['time_vs_task_indicators', 'time_vs_rewards', 'time_vs_pos_const_specification'],],
        )
    ),
    cheetah_target_config
)

cheetah_target_config = prepare_variant_file(cheetah_target_config)
fig, ax = analysis(cheetah_target_config)
fig.suptitle('Target, itr. 500', size=30)
fig.tight_layout()
# Out:
# 2022-02-16 14:09:30.126584 CET | Variant:
# 2022-02-16 14:09:30.127420 CET | {
#   "env_name": "cheetah-stationary-target-normalizedReward-allT",
#   "env_params": {
#     "n_train_tasks": 100,
#     "n_eval_tasks": 30,
#     "use_normalized_env": true,
#     "scripted_policy": false,
#     "use_state_decoder": true,
#     "change_mode": "location",
#     "change_point_interval": 1,
#     "negative_change_point_basis": -1000000,
#     "positive_change_point_basis": 1000000,
#     "state_reconstruction_clip": 8,
#     "task_max_target": 25.0,
#     "task_min_target": 5.0,
#     "termination_possible": false
#   },
#   "path_to_weights": "../../output/cheetah-stationary-target-normalizedReward-allT/2022_02_13_00_46_57",
#   "train_or_showcase": "train",
#   "showcase_itr": 500,
#   "util_params": {
#     "base_log_dir": ".temp",
#     "temp_dir": ".temp_cemrl",
#     "use_gpu": true,
#     "use_multiprocessing": false,
#     "num_workers": 8,
#     "gpu_id": 0,
#     "debug": false,
#     "debug_encoding": false,
#     "plot": false
#   },
#   "algo_params": {
#     "policy_mode": "sac_single",
#     "num_policy_nets": 1,
#     "use_relabeler": false,
#     "use_combination_trainer": false,
#     "use_data_normalization": true,
#     "use_sac_data_normalization": false,
#     "use_parametrized_alpha": false,
#     "encoder_type": "TimestepMLP",
#     "encoder_merge_mode": "add",
#     "use_fixed_seeding": true,
#     "seed": 0,
#     "batch_size_reconstruction": 256,
#     "batch_size_validation": 4096,
#     "batch_size_combination": 256,
#     "batch_size_policy": 256,
#     "batch_size_relabel": 1024,
#     "time_steps": 30,
#     "latent_size": 1,
#     "sac_layer_size": 300,
#     "max_replay_buffer_size": 10000000,
#     "sampling_mode": null,
#     "num_last_samples": 10000000,
#     "permute_samples": false,
#     "num_train_epochs": 501,
#     "snapshot_gap": 10,
#     "num_reconstruction_steps": 5000,
#     "num_policy_steps": 2000,
#     "num_train_tasks_per_episode": 20,
#     "num_transitions_initial": 0,
#     "num_transitions_per_episode": 200,
#     "num_eval_trajectories": 2,
#     "showcase_every": 0,
#     "num_showcase_deterministic": 1,
#     "num_showcase_non_deterministic": 1,
#     "max_path_length": 200,
#     "target_entropy_factor": 1.0,
#     "sac_alpha": 1.0,
#     "lr_policy": 0.0003,
#     "lr_qf": 0.0003,
#     "data_usage_reconstruction": null,
#     "data_usage_sac": null
#   },
#   "reconstruction_params": {
#     "use_state_diff": false,
#     "reconstruct_all_timesteps": true,
#     "component_constraint_learning": false,
#     "prior_mode": "fixedOnY",
#     "prior_sigma": 0.5,
#     "num_classes": 1,
#     "lr_encoder": 0.0003,
#     "lr_decoder": 0.0003,
#     "alpha_kl_z": 0.001,
#     "beta_kl_y": 0.001,
#     "net_complex_enc_dec": 10.0,
#     "factor_qf_loss": 1.0,
#     "train_val_percent": 0.8,
#     "eval_interval": 50,
#     "early_stopping_threshold": 500
#   },
#   "save_dir": null,
#   "analysis_params": {
#     "train_example_cases": [],
#     "example_cases": [
#       6,
#       7,
#       8,
#       9,
#       24
#     ],
#     "single_episode_plots": [],
#     "multiple_episode_plots": "[['time_vs_task_indicators', 'time_vs_rewards', 'time_vs_pos_const_specification']]",
#     "plot_encoding": false,
#     "log_and_plot_progress": false,
#     "save": false,
#     "show": false,
#     "manipulate_time_steps": false,
#     "manipulate_change_trigger": false,
#     "manipulate_max_path_length": false,
#     "manipulate_test_task_number": false,
#     "visualize_run": false
#   },
#   "exp_name": "2022_02_16_14_09_30"
# }

# %%
cheetah_target_config = copy.deepcopy(base_config)
cheetah_target_config = deep_update_dict(
    dict(
        path_to_weights='../../output/cheetah-stationary-target-normalizedReward-allT/2022_02_14_17_39_50',
        showcase_itr=500,
        analysis_params=dict(
            example_cases=[6, 7, 8, 9, 24, ],  # CONFIGURE! choose an array of test tasks
            multiple_episode_plots=[['time_vs_task_indicators', 'time_vs_rewards', 'time_vs_pos_const_specification'],],
        )
    ),
    cheetah_target_config
)

cheetah_target_config = prepare_variant_file(cheetah_target_config)
fig, ax = analysis(cheetah_target_config)
fig.suptitle('Target, itr. 500', size=30)
fig.tight_layout()
# Out:
# 2022-02-16 14:10:33.960569 CET | [2022_02_16_14_09_30] Variant:
# 2022-02-16 14:10:33.961608 CET | [2022_02_16_14_09_30] {
#   "env_name": "cheetah-stationary-target-normalizedReward-allT",
#   "env_params": {
#     "n_train_tasks": 100,
#     "n_eval_tasks": 30,
#     "use_normalized_env": true,
#     "scripted_policy": false,
#     "use_state_decoder": true,
#     "change_mode": "location",
#     "change_point_interval": 1,
#     "negative_change_point_basis": -1000000,
#     "positive_change_point_basis": 1000000,
#     "state_reconstruction_clip": 8,
#     "task_max_target": 25.0,
#     "task_min_target": 5.0,
#     "termination_possible": false
#   },
#   "path_to_weights": "../../output/cheetah-stationary-target-normalizedReward-allT/2022_02_14_17_39_50",
#   "train_or_showcase": "train",
#   "showcase_itr": 500,
#   "util_params": {
#     "base_log_dir": ".temp",
#     "temp_dir": ".temp_cemrl",
#     "use_gpu": true,
#     "use_multiprocessing": false,
#     "num_workers": 8,
#     "gpu_id": 0,
#     "debug": false,
#     "debug_encoding": false,
#     "plot": false
#   },
#   "algo_params": {
#     "policy_mode": "sac_single",
#     "num_policy_nets": 1,
#     "use_relabeler": false,
#     "use_combination_trainer": false,
#     "use_data_normalization": true,
#     "use_sac_data_normalization": false,
#     "use_parametrized_alpha": false,
#     "encoder_type": "TimestepMLP",
#     "encoder_merge_mode": "add",
#     "use_fixed_seeding": true,
#     "seed": 0,
#     "batch_size_reconstruction": 256,
#     "batch_size_validation": 4096,
#     "batch_size_combination": 256,
#     "batch_size_policy": 256,
#     "batch_size_relabel": 1024,
#     "time_steps": 30,
#     "latent_size": 1,
#     "sac_layer_size": 300,
#     "max_replay_buffer_size": 10000000,
#     "sampling_mode": null,
#     "num_last_samples": 10000000,
#     "permute_samples": false,
#     "num_train_epochs": 501,
#     "snapshot_gap": 10,
#     "num_reconstruction_steps": 5000,
#     "num_policy_steps": 2000,
#     "num_train_tasks_per_episode": 20,
#     "num_transitions_initial": 0,
#     "num_transitions_per_episode": 200,
#     "num_eval_trajectories": 2,
#     "showcase_every": 0,
#     "num_showcase_deterministic": 1,
#     "num_showcase_non_deterministic": 1,
#     "max_path_length": 200,
#     "target_entropy_factor": 1.0,
#     "sac_alpha": 1.0,
#     "lr_policy": 0.0003,
#     "lr_qf": 0.0003,
#     "data_usage_reconstruction": null,
#     "data_usage_sac": null
#   },
#   "reconstruction_params": {
#     "use_state_diff": false,
#     "reconstruct_all_timesteps": true,
#     "component_constraint_learning": false,
#     "prior_mode": "fixedOnY",
#     "prior_sigma": 0.5,
#     "num_classes": 1,
#     "lr_encoder": 0.0003,
#     "lr_decoder": 0.0003,
#     "alpha_kl_z": 0.001,
#     "beta_kl_y": 0.001,
#     "net_complex_enc_dec": 10.0,
#     "factor_qf_loss": 1.0,
#     "train_val_percent": 0.8,
#     "eval_interval": 50,
#     "early_stopping_threshold": 500
#   },
#   "save_dir": null,
#   "analysis_params": {
#     "train_example_cases": [],
#     "example_cases": [
#       6,
#       7,
#       8,
#       9,
#       24
#     ],
#     "single_episode_plots": [],
#     "multiple_episode_plots": "[['time_vs_task_indicators', 'time_vs_rewards', 'time_vs_pos_const_specification']]",
#     "plot_encoding": false,
#     "log_and_plot_progress": false,
#     "save": false,
#     "show": false,
#     "manipulate_time_steps": false,
#     "manipulate_change_trigger": false,
#     "manipulate_max_path_length": false,
#     "manipulate_test_task_number": false,
#     "visualize_run": false
#   },
#   "exp_name": "2022_02_16_14_10_33"
# }

# %% [markdown]
# # GRU Encoder

# %%
cheetah_target_config = copy.deepcopy(base_config)
target_itr = 425
cheetah_target_config = deep_update_dict(
    dict(
        path_to_weights='../../output/cheetah-stationary-target-normalizedReward-allT-GRU/2022_02_13_00_47_43',
        showcase_itr=target_itr,
        analysis_params=dict(
            example_cases=[6, 7, 8, 9, 24, ],  # CONFIGURE! choose an array of test tasks
            multiple_episode_plots=[['time_vs_task_indicators', 'time_vs_rewards', 'time_vs_pos_const_specification'],],
        )
    ),
    cheetah_target_config
)

cheetah_target_config = prepare_variant_file(cheetah_target_config)
fig, ax = analysis(cheetah_target_config)
fig.suptitle(f'Target, itr. {target_itr}', size=30)
fig.tight_layout()
# Out:
# 2022-02-16 14:36:31.618955 CET | [2022_02_16_14_09_30] [2022_02_16_14_10_33] [2022_02_16_14_13_57] [2022_02_16_14_14_21] [2022_02_16_14_14_58] [2022_02_16_14_15_13] [2022_02_16_14_16_01] [2022_02_16_14_16_51] [2022_02_16_14_17_43] [2022_02_16_14_18_21] [2022_02_16_14_19_25] [2022_02_16_14_22_54] [2022_02_16_14_23_05] Variant:
# 2022-02-16 14:36:31.621481 CET | [2022_02_16_14_09_30] [2022_02_16_14_10_33] [2022_02_16_14_13_57] [2022_02_16_14_14_21] [2022_02_16_14_14_58] [2022_02_16_14_15_13] [2022_02_16_14_16_01] [2022_02_16_14_16_51] [2022_02_16_14_17_43] [2022_02_16_14_18_21] [2022_02_16_14_19_25] [2022_02_16_14_22_54] [2022_02_16_14_23_05] {
#   "env_name": "cheetah-stationary-target-normalizedReward-allT-GRU",
#   "env_params": {
#     "n_train_tasks": 100,
#     "n_eval_tasks": 30,
#     "use_normalized_env": true,
#     "scripted_policy": false,
#     "use_state_decoder": true,
#     "change_mode": "location",
#     "change_point_interval": 1,
#     "negative_change_point_basis": -1000000,
#     "positive_change_point_basis": 1000000,
#     "state_reconstruction_clip": 8,
#     "task_max_target": 25.0,
#     "task_min_target": 5.0,
#     "termination_possible": false
#   },
#   "path_to_weights": "../../output/cheetah-stationary-target-normalizedReward-allT-GRU/2022_02_13_00_47_43",
#   "train_or_showcase": "train",
#   "showcase_itr": 425,
#   "util_params": {
#     "base_log_dir": ".temp",
#     "temp_dir": ".temp_cemrl",
#     "use_gpu": true,
#     "use_multiprocessing": false,
#     "num_workers": 8,
#     "gpu_id": 0,
#     "debug": false,
#     "debug_encoding": false,
#     "plot": false
#   },
#   "algo_params": {
#     "policy_mode": "sac_single",
#     "num_policy_nets": 1,
#     "use_relabeler": false,
#     "use_combination_trainer": false,
#     "use_data_normalization": true,
#     "use_sac_data_normalization": false,
#     "use_parametrized_alpha": false,
#     "encoder_type": "GRU",
#     "encoder_merge_mode": "add",
#     "use_fixed_seeding": true,
#     "seed": 0,
#     "batch_size_reconstruction": 256,
#     "batch_size_validation": 4096,
#     "batch_size_combination": 256,
#     "batch_size_policy": 256,
#     "batch_size_relabel": 1024,
#     "time_steps": 30,
#     "latent_size": 1,
#     "sac_layer_size": 300,
#     "max_replay_buffer_size": 10000000,
#     "sampling_mode": null,
#     "num_last_samples": 10000000,
#     "permute_samples": false,
#     "num_train_epochs": 501,
#     "snapshot_gap": 10,
#     "num_reconstruction_steps": 5000,
#     "num_policy_steps": 2000,
#     "num_train_tasks_per_episode": 20,
#     "num_transitions_initial": 0,
#     "num_transitions_per_episode": 200,
#     "num_eval_trajectories": 2,
#     "showcase_every": 0,
#     "num_showcase_deterministic": 1,
#     "num_showcase_non_deterministic": 1,
#     "max_path_length": 200,
#     "target_entropy_factor": 1.0,
#     "sac_alpha": 1.0,
#     "lr_policy": 0.0003,
#     "lr_qf": 0.0003,
#     "data_usage_reconstruction": null,
#     "data_usage_sac": null
#   },
#   "reconstruction_params": {
#     "use_state_diff": false,
#     "reconstruct_all_timesteps": true,
#     "component_constraint_learning": false,
#     "prior_mode": "fixedOnY",
#     "prior_sigma": 0.5,
#     "num_classes": 1,
#     "lr_encoder": 0.0003,
#     "lr_decoder": 0.0003,
#     "alpha_kl_z": 0.001,
#     "beta_kl_y": 0.001,
#     "net_complex_enc_dec": 10.0,
#     "factor_qf_loss": 1.0,
#     "train_val_percent": 0.8,
#     "eval_interval": 50,
#     "early_stopping_threshold": 500
#   },
#   "save_dir": null,
#   "analysis_params": {
#     "train_example_cases": [],
#     "example_cases": [
#       6,
#       7,
#       8,
#       9,
#       24
#     ],
#     "single_episode_plots": [],
#     "multiple_episode_plots": "[['time_vs_task_indicators', 'time_vs_rewards', 'time_vs_pos_const_specification']]",
#     "plot_encoding": false,
#     "log_and_plot_progress": false,
#     "save": false,
#     "show": false,
#     "manipulate_time_steps": false,
#     "manipulate_change_trigger": false,
#     "manipulate_max_path_length": false,
#     "manipulate_test_task_number": false,
#     "visualize_run": false
#   },
#   "exp_name": "2022_02_16_14_36_31"
# }

# %%
cheetah_target_config = copy.deepcopy(base_config)
target_itr = 500
cheetah_target_config = deep_update_dict(
    dict(
        path_to_weights='../../output/cheetah-stationary-target-normalizedReward-allT-GRU/2022_02_16_17_21_12',
        showcase_itr=target_itr,
        analysis_params=dict(
            example_cases=[6, 7, 8, 9, 24, ],  # CONFIGURE! choose an array of test tasks
            multiple_episode_plots=[['time_vs_task_indicators', 'time_vs_rewards', 'time_vs_pos_const_specification'],],
        )
    ),
    cheetah_target_config
)

cheetah_target_config = prepare_variant_file(cheetah_target_config)
fig, ax = analysis(cheetah_target_config)
fig.suptitle(f'Target, itr. {target_itr}', size=30)
fig.tight_layout()
# Out:
# 2022-02-17 13:32:28.415869 CET | [2022_02_17_13_31_55] Variant:
# 2022-02-17 13:32:28.423572 CET | [2022_02_17_13_31_55] {
#   "env_name": "cheetah-stationary-target-normalizedReward-allT-GRU",
#   "env_params": {
#     "n_train_tasks": 100,
#     "n_eval_tasks": 30,
#     "use_normalized_env": true,
#     "scripted_policy": false,
#     "use_state_decoder": true,
#     "change_mode": "location",
#     "change_point_interval": 1,
#     "negative_change_point_basis": -1000000,
#     "positive_change_point_basis": 1000000,
#     "state_reconstruction_clip": 8,
#     "task_max_target": 25.0,
#     "task_min_target": 5.0,
#     "termination_possible": false
#   },
#   "path_to_weights": "../../output/cheetah-stationary-target-normalizedReward-allT-GRU/2022_02_16_17_21_12",
#   "train_or_showcase": "train",
#   "showcase_itr": 500,
#   "util_params": {
#     "base_log_dir": ".temp",
#     "temp_dir": ".temp_cemrl",
#     "use_gpu": true,
#     "use_multiprocessing": false,
#     "num_workers": 8,
#     "gpu_id": 0,
#     "debug": false,
#     "debug_encoding": false,
#     "plot": false
#   },
#   "algo_params": {
#     "policy_mode": "sac_single",
#     "num_policy_nets": 1,
#     "use_relabeler": false,
#     "use_combination_trainer": false,
#     "use_data_normalization": true,
#     "use_sac_data_normalization": false,
#     "use_parametrized_alpha": false,
#     "encoder_type": "GRU",
#     "encoder_merge_mode": "add",
#     "use_fixed_seeding": true,
#     "seed": 0,
#     "batch_size_reconstruction": 256,
#     "batch_size_validation": 4096,
#     "batch_size_combination": 256,
#     "batch_size_policy": 256,
#     "batch_size_relabel": 1024,
#     "time_steps": 30,
#     "latent_size": 1,
#     "sac_layer_size": 300,
#     "max_replay_buffer_size": 10000000,
#     "sampling_mode": null,
#     "num_last_samples": 10000000,
#     "permute_samples": false,
#     "num_train_epochs": 501,
#     "snapshot_gap": 10,
#     "num_reconstruction_steps": 5000,
#     "num_policy_steps": 2000,
#     "num_train_tasks_per_episode": 20,
#     "num_transitions_initial": 0,
#     "num_transitions_per_episode": 200,
#     "num_eval_trajectories": 2,
#     "showcase_every": 0,
#     "num_showcase_deterministic": 1,
#     "num_showcase_non_deterministic": 1,
#     "max_path_length": 200,
#     "target_entropy_factor": 1.0,
#     "sac_alpha": 1.0,
#     "lr_policy": 0.0003,
#     "lr_qf": 0.0003,
#     "data_usage_reconstruction": null,
#     "data_usage_sac": null
#   },
#   "reconstruction_params": {
#     "use_state_diff": false,
#     "reconstruct_all_timesteps": true,
#     "component_constraint_learning": false,
#     "prior_mode": "fixedOnY",
#     "prior_sigma": 0.5,
#     "num_classes": 1,
#     "lr_encoder": 0.0003,
#     "lr_decoder": 0.0003,
#     "alpha_kl_z": 0.001,
#     "beta_kl_y": 0.001,
#     "net_complex_enc_dec": 10.0,
#     "factor_qf_loss": 1.0,
#     "train_val_percent": 0.8,
#     "eval_interval": 50,
#     "early_stopping_threshold": 500
#   },
#   "save_dir": null,
#   "analysis_params": {
#     "train_example_cases": [],
#     "example_cases": [
#       6,
#       7,
#       8,
#       9,
#       24
#     ],
#     "single_episode_plots": [],
#     "multiple_episode_plots": "[['time_vs_task_indicators', 'time_vs_rewards', 'time_vs_pos_const_specification']]",
#     "plot_encoding": false,
#     "log_and_plot_progress": false,
#     "save": false,
#     "show": false,
#     "manipulate_time_steps": false,
#     "manipulate_change_trigger": false,
#     "manipulate_max_path_length": false,
#     "manipulate_test_task_number": false,
#     "visualize_run": false
#   },
#   "exp_name": "2022_02_17_13_32_28"
# }

# %% [markdown]
# # 1D Conv Encoder

# %%
cheetah_target_config = copy.deepcopy(base_config)
target_itr = 300
cheetah_target_config = deep_update_dict(
    dict(
        path_to_weights='../../output/cheetah-stationary-target-normalizedReward-allT-Conv/2022_02_15_16_12_25',
        showcase_itr=target_itr,
        analysis_params=dict(
            example_cases=[6, 7, 8, 9, 24, ],  # CONFIGURE! choose an array of test tasks
            multiple_episode_plots=[['time_vs_task_indicators', 'time_vs_rewards', 'time_vs_pos_const_specification'],],
        )
    ),
    cheetah_target_config
)

cheetah_target_config = prepare_variant_file(cheetah_target_config)
fig, ax = analysis(cheetah_target_config)
fig.suptitle(f'Target, itr. {target_itr}', size=30)
fig.tight_layout()
# Out:
# 2022-02-16 14:18:21.090942 CET | [2022_02_16_14_09_30] [2022_02_16_14_10_33] [2022_02_16_14_13_57] [2022_02_16_14_14_21] [2022_02_16_14_14_58] [2022_02_16_14_15_13] [2022_02_16_14_16_01] [2022_02_16_14_16_51] [2022_02_16_14_17_43] Variant:
# 2022-02-16 14:18:21.092406 CET | [2022_02_16_14_09_30] [2022_02_16_14_10_33] [2022_02_16_14_13_57] [2022_02_16_14_14_21] [2022_02_16_14_14_58] [2022_02_16_14_15_13] [2022_02_16_14_16_01] [2022_02_16_14_16_51] [2022_02_16_14_17_43] {
#   "env_name": "cheetah-stationary-target-normalizedReward-allT-Conv",
#   "env_params": {
#     "n_train_tasks": 100,
#     "n_eval_tasks": 30,
#     "use_normalized_env": true,
#     "scripted_policy": false,
#     "use_state_decoder": true,
#     "change_mode": "location",
#     "change_point_interval": 1,
#     "negative_change_point_basis": -1000000,
#     "positive_change_point_basis": 1000000,
#     "state_reconstruction_clip": 8,
#     "task_max_target": 25.0,
#     "task_min_target": 5.0,
#     "termination_possible": false
#   },
#   "path_to_weights": "../../output/cheetah-stationary-target-normalizedReward-allT-Conv/2022_02_15_16_12_25",
#   "train_or_showcase": "train",
#   "showcase_itr": 300,
#   "util_params": {
#     "base_log_dir": ".temp",
#     "temp_dir": ".temp_cemrl",
#     "use_gpu": true,
#     "use_multiprocessing": false,
#     "num_workers": 8,
#     "gpu_id": 0,
#     "debug": false,
#     "debug_encoding": false,
#     "plot": false
#   },
#   "algo_params": {
#     "policy_mode": "sac_single",
#     "num_policy_nets": 1,
#     "use_relabeler": false,
#     "use_combination_trainer": false,
#     "use_data_normalization": true,
#     "use_sac_data_normalization": false,
#     "use_parametrized_alpha": false,
#     "encoder_type": "Conv",
#     "encoder_merge_mode": "add",
#     "use_fixed_seeding": true,
#     "seed": 0,
#     "batch_size_reconstruction": 256,
#     "batch_size_validation": 4096,
#     "batch_size_combination": 256,
#     "batch_size_policy": 256,
#     "batch_size_relabel": 1024,
#     "time_steps": 30,
#     "latent_size": 1,
#     "sac_layer_size": 300,
#     "max_replay_buffer_size": 10000000,
#     "sampling_mode": null,
#     "num_last_samples": 10000000,
#     "permute_samples": false,
#     "num_train_epochs": 501,
#     "snapshot_gap": 10,
#     "num_reconstruction_steps": 5000,
#     "num_policy_steps": 2000,
#     "num_train_tasks_per_episode": 20,
#     "num_transitions_initial": 0,
#     "num_transitions_per_episode": 200,
#     "num_eval_trajectories": 2,
#     "showcase_every": 0,
#     "num_showcase_deterministic": 1,
#     "num_showcase_non_deterministic": 1,
#     "max_path_length": 200,
#     "target_entropy_factor": 1.0,
#     "sac_alpha": 1.0,
#     "lr_policy": 0.0003,
#     "lr_qf": 0.0003,
#     "data_usage_reconstruction": null,
#     "data_usage_sac": null
#   },
#   "reconstruction_params": {
#     "use_state_diff": false,
#     "reconstruct_all_timesteps": true,
#     "component_constraint_learning": false,
#     "prior_mode": "fixedOnY",
#     "prior_sigma": 0.5,
#     "num_classes": 1,
#     "lr_encoder": 0.0003,
#     "lr_decoder": 0.0003,
#     "alpha_kl_z": 0.001,
#     "beta_kl_y": 0.001,
#     "net_complex_enc_dec": 10.0,
#     "factor_qf_loss": 1.0,
#     "train_val_percent": 0.8,
#     "eval_interval": 50,
#     "early_stopping_threshold": 500
#   },
#   "save_dir": null,
#   "analysis_params": {
#     "train_example_cases": [],
#     "example_cases": [
#       6,
#       7,
#       8,
#       9,
#       24
#     ],
#     "single_episode_plots": [],
#     "multiple_episode_plots": "[['time_vs_task_indicators', 'time_vs_rewards', 'time_vs_pos_const_specification']]",
#     "plot_encoding": false,
#     "log_and_plot_progress": false,
#     "save": false,
#     "show": false,
#     "manipulate_time_steps": false,
#     "manipulate_change_trigger": false,
#     "manipulate_max_path_length": false,
#     "manipulate_test_task_number": false,
#     "visualize_run": false
#   },
#   "exp_name": "2022_02_16_14_18_21"
# }

# %%
cheetah_target_config = copy.deepcopy(base_config)
target_itr = 325
cheetah_target_config = deep_update_dict(
    dict(
        path_to_weights='../../output/cheetah-stationary-target-normalizedReward-allT-Conv/2022_02_16_01_47_31',
        showcase_itr=target_itr,
        analysis_params=dict(
            example_cases=[6, 7, 8, 9, 24, ],  # CONFIGURE! choose an array of test tasks
            multiple_episode_plots=[['time_vs_task_indicators', 'time_vs_rewards', 'time_vs_pos_const_specification'],],
        )
    ),
    cheetah_target_config
)

cheetah_target_config = prepare_variant_file(cheetah_target_config)
fig, ax = analysis(cheetah_target_config)
fig.suptitle(f'Target, itr. {target_itr}', size=30)
fig.tight_layout()
# Out:
# 2022-02-16 14:19:25.605154 CET | [2022_02_16_14_09_30] [2022_02_16_14_10_33] [2022_02_16_14_13_57] [2022_02_16_14_14_21] [2022_02_16_14_14_58] [2022_02_16_14_15_13] [2022_02_16_14_16_01] [2022_02_16_14_16_51] [2022_02_16_14_17_43] [2022_02_16_14_18_21] Variant:
# 2022-02-16 14:19:25.606476 CET | [2022_02_16_14_09_30] [2022_02_16_14_10_33] [2022_02_16_14_13_57] [2022_02_16_14_14_21] [2022_02_16_14_14_58] [2022_02_16_14_15_13] [2022_02_16_14_16_01] [2022_02_16_14_16_51] [2022_02_16_14_17_43] [2022_02_16_14_18_21] {
#   "env_name": "cheetah-stationary-target-normalizedReward-allT-Conv",
#   "env_params": {
#     "n_train_tasks": 100,
#     "n_eval_tasks": 30,
#     "use_normalized_env": true,
#     "scripted_policy": false,
#     "use_state_decoder": true,
#     "change_mode": "location",
#     "change_point_interval": 1,
#     "negative_change_point_basis": -1000000,
#     "positive_change_point_basis": 1000000,
#     "state_reconstruction_clip": 8,
#     "task_max_target": 25.0,
#     "task_min_target": 5.0,
#     "termination_possible": false
#   },
#   "path_to_weights": "../../output/cheetah-stationary-target-normalizedReward-allT-Conv/2022_02_16_01_47_31",
#   "train_or_showcase": "train",
#   "showcase_itr": 325,
#   "util_params": {
#     "base_log_dir": ".temp",
#     "temp_dir": ".temp_cemrl",
#     "use_gpu": true,
#     "use_multiprocessing": false,
#     "num_workers": 8,
#     "gpu_id": 0,
#     "debug": false,
#     "debug_encoding": false,
#     "plot": false
#   },
#   "algo_params": {
#     "policy_mode": "sac_single",
#     "num_policy_nets": 1,
#     "use_relabeler": false,
#     "use_combination_trainer": false,
#     "use_data_normalization": true,
#     "use_sac_data_normalization": false,
#     "use_parametrized_alpha": false,
#     "encoder_type": "Conv",
#     "encoder_merge_mode": "add",
#     "use_fixed_seeding": true,
#     "seed": 0,
#     "batch_size_reconstruction": 256,
#     "batch_size_validation": 4096,
#     "batch_size_combination": 256,
#     "batch_size_policy": 256,
#     "batch_size_relabel": 1024,
#     "time_steps": 30,
#     "latent_size": 1,
#     "sac_layer_size": 300,
#     "max_replay_buffer_size": 10000000,
#     "sampling_mode": null,
#     "num_last_samples": 10000000,
#     "permute_samples": false,
#     "num_train_epochs": 501,
#     "snapshot_gap": 10,
#     "num_reconstruction_steps": 5000,
#     "num_policy_steps": 2000,
#     "num_train_tasks_per_episode": 20,
#     "num_transitions_initial": 0,
#     "num_transitions_per_episode": 200,
#     "num_eval_trajectories": 2,
#     "showcase_every": 0,
#     "num_showcase_deterministic": 1,
#     "num_showcase_non_deterministic": 1,
#     "max_path_length": 200,
#     "target_entropy_factor": 1.0,
#     "sac_alpha": 1.0,
#     "lr_policy": 0.0003,
#     "lr_qf": 0.0003,
#     "data_usage_reconstruction": null,
#     "data_usage_sac": null
#   },
#   "reconstruction_params": {
#     "use_state_diff": false,
#     "reconstruct_all_timesteps": true,
#     "component_constraint_learning": false,
#     "prior_mode": "fixedOnY",
#     "prior_sigma": 0.5,
#     "num_classes": 1,
#     "lr_encoder": 0.0003,
#     "lr_decoder": 0.0003,
#     "alpha_kl_z": 0.001,
#     "beta_kl_y": 0.001,
#     "net_complex_enc_dec": 10.0,
#     "factor_qf_loss": 1.0,
#     "train_val_percent": 0.8,
#     "eval_interval": 50,
#     "early_stopping_threshold": 500
#   },
#   "save_dir": null,
#   "analysis_params": {
#     "train_example_cases": [],
#     "example_cases": [
#       6,
#       7,
#       8,
#       9,
#       24
#     ],
#     "single_episode_plots": [],
#     "multiple_episode_plots": "[['time_vs_task_indicators', 'time_vs_rewards', 'time_vs_pos_const_specification']]",
#     "plot_encoding": false,
#     "log_and_plot_progress": false,
#     "save": false,
#     "show": false,
#     "manipulate_time_steps": false,
#     "manipulate_change_trigger": false,
#     "manipulate_max_path_length": false,
#     "manipulate_test_task_number": false,
#     "visualize_run": false
#   },
#   "exp_name": "2022_02_16_14_19_25"
# }
# /home/philipp/miniconda3/envs/cemrl/lib/python3.9/site-packages/torch/nn/modules/lazy.py:178: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '

# %% [markdown]
# # Partial success with full window reconstruction

# %%
cheetah_target_config = copy.deepcopy(base_config)
cheetah_target_config = deep_update_dict(
    dict(
        path_to_weights='../../output/cheetah-stationary-target-allT/2022_02_01_17_28_27',
        showcase_itr=350,
        analysis_params=dict(
            example_cases=[6, 7, 8, 9, 24, ],  # CONFIGURE! choose an array of test tasks
            multiple_episode_plots=[['time_vs_task_indicators', 'time_vs_rewards', 'time_vs_pos_const_specification'],],
        )
    ),
    cheetah_target_config
)

cheetah_target_config = prepare_variant_file(cheetah_target_config)
fig, ax = analysis(cheetah_target_config)
fig.suptitle('Target (changed reward fct.), itr. 500', size=30)
fig.tight_layout()
# Out:
# 2022-02-03 19:32:53.141823 CET | [2022_02_03_18_27_15] [2022_02_03_18_28_30] [2022_02_03_18_28_56] [2022_02_03_18_31_20] [2022_02_03_18_31_37] [2022_02_03_18_32_54] [2022_02_03_18_34_24] [2022_02_03_18_34_35] [2022_02_03_18_34_45] [2022_02_03_18_35_19] [2022_02_03_18_36_39] [2022_02_03_18_37_44] [2022_02_03_18_37_51] [2022_02_03_18_38_05] [2022_02_03_18_38_20] [2022_02_03_18_40_16] [2022_02_03_18_40_53] [2022_02_03_18_42_05] [2022_02_03_18_44_45] [2022_02_03_18_44_54] [2022_02_03_18_46_48] [2022_02_03_18_47_42] [2022_02_03_18_48_07] [2022_02_03_18_48_34] [2022_02_03_18_57_41] [2022_02_03_18_59_07] [2022_02_03_19_00_22] [2022_02_03_19_00_38] [2022_02_03_19_01_40] [2022_02_03_19_02_10] [2022_02_03_19_22_10] [2022_02_03_19_23_17] [2022_02_03_19_23_22] [2022_02_03_19_23_28] [2022_02_03_19_26_04] [2022_02_03_19_26_49] [2022_02_03_19_30_46] [2022_02_03_19_30_49] Variant:
# 2022-02-03 19:32:53.144951 CET | [2022_02_03_18_27_15] [2022_02_03_18_28_30] [2022_02_03_18_28_56] [2022_02_03_18_31_20] [2022_02_03_18_31_37] [2022_02_03_18_32_54] [2022_02_03_18_34_24] [2022_02_03_18_34_35] [2022_02_03_18_34_45] [2022_02_03_18_35_19] [2022_02_03_18_36_39] [2022_02_03_18_37_44] [2022_02_03_18_37_51] [2022_02_03_18_38_05] [2022_02_03_18_38_20] [2022_02_03_18_40_16] [2022_02_03_18_40_53] [2022_02_03_18_42_05] [2022_02_03_18_44_45] [2022_02_03_18_44_54] [2022_02_03_18_46_48] [2022_02_03_18_47_42] [2022_02_03_18_48_07] [2022_02_03_18_48_34] [2022_02_03_18_57_41] [2022_02_03_18_59_07] [2022_02_03_19_00_22] [2022_02_03_19_00_38] [2022_02_03_19_01_40] [2022_02_03_19_02_10] [2022_02_03_19_22_10] [2022_02_03_19_23_17] [2022_02_03_19_23_22] [2022_02_03_19_23_28] [2022_02_03_19_26_04] [2022_02_03_19_26_49] [2022_02_03_19_30_46] [2022_02_03_19_30_49] {
#   "env_name": "cheetah-stationary-target-allT",
#   "env_params": {
#     "n_train_tasks": 100,
#     "n_eval_tasks": 30,
#     "use_normalized_env": true,
#     "scripted_policy": false,
#     "use_state_decoder": true,
#     "change_mode": "location",
#     "change_point_interval": 1,
#     "negative_change_point_basis": -1000000,
#     "positive_change_point_basis": 1000000,
#     "state_reconstruction_clip": 8,
#     "task_max_velocity": 3.0,
#     "task_min_velocity": 0.0,
#     "termination_possible": false,
#     "task_max_target": 25.0,
#     "task_min_target": 5.0
#   },
#   "path_to_weights": "../../output/cheetah-stationary-target-allT/2022_02_01_17_28_27",
#   "train_or_showcase": "train",
#   "showcase_itr": 350,
#   "util_params": {
#     "base_log_dir": ".temp",
#     "temp_dir": ".temp_cemrl",
#     "use_gpu": true,
#     "use_multiprocessing": false,
#     "num_workers": 8,
#     "gpu_id": 0,
#     "debug": false,
#     "debug_encoding": true,
#     "plot": false
#   },
#   "algo_params": {
#     "policy_mode": "sac_single",
#     "num_policy_nets": 1,
#     "use_relabeler": true,
#     "use_combination_trainer": false,
#     "use_data_normalization": true,
#     "use_parametrized_alpha": false,
#     "encoding_mode": "transitionSharedY",
#     "merge_mode": "add",
#     "use_fixed_seeding": true,
#     "seed": 0,
#     "batch_size_reconstruction": 256,
#     "batch_size_validation": 4096,
#     "batch_size_combination": 256,
#     "batch_size_policy": 256,
#     "batch_size_relabel": 1024,
#     "time_steps": 30,
#     "latent_size": 1,
#     "sac_layer_size": 300,
#     "max_replay_buffer_size": 10000000,
#     "sampling_mode": null,
#     "num_last_samples": 10000000,
#     "permute_samples": false,
#     "num_train_epochs": 501,
#     "snapshot_gap": 10,
#     "num_reconstruction_steps": 5000,
#     "num_policy_steps": 2000,
#     "num_train_tasks_per_episode": 20,
#     "num_transitions_initial": 0,
#     "num_transitions_per_episode": 200,
#     "num_eval_trajectories": 2,
#     "showcase_every": 0,
#     "num_showcase_deterministic": 1,
#     "num_showcase_non_deterministic": 1,
#     "max_path_length": 200,
#     "target_entropy_factor": 1.0,
#     "sac_alpha": 1.0,
#     "lr_policy": 0.0003,
#     "lr_qf": 0.0003,
#     "data_usage_reconstruction": null,
#     "data_usage_sac": null
#   },
#   "reconstruction_params": {
#     "use_state_diff": false,
#     "reconstruct_all_timesteps": true,
#     "component_constraint_learning": false,
#     "prior_mode": "fixedOnY",
#     "prior_sigma": 0.5,
#     "num_classes": 1,
#     "lr_encoder": 0.0003,
#     "lr_decoder": 0.0003,
#     "alpha_kl_z": 0.001,
#     "beta_kl_y": 0.001,
#     "net_complex_enc_dec": 10.0,
#     "factor_qf_loss": 1.0,
#     "train_val_percent": 0.8,
#     "eval_interval": 50,
#     "early_stopping_threshold": 500,
#     "temp_folder": ".temp_cemrl"
#   },
#   "save_dir": null,
#   "analysis_params": {
#     "train_example_cases": [],
#     "example_cases": [
#       6,
#       7,
#       8,
#       9,
#       24
#     ],
#     "single_episode_plots": [],
#     "multiple_episode_plots": "[['time_vs_task_indicators', 'time_vs_rewards', 'time_vs_pos_const_specification']]",
#     "save": false,
#     "manipulate_timesteps": false,
#     "manipulate_time_steps": false,
#     "manipulate_change_trigger": false,
#     "manipulate_max_path_length": false,
#     "manipulate_test_task_number": false,
#     "plot_encoding": false,
#     "log_and_plot_progress": false,
#     "visualize_run": false,
#     "show": false
#   },
#   "exp_name": "2022_02_03_19_32_53"
# }

# %%
cheetah_target_config = copy.deepcopy(base_config)
cheetah_target_config = deep_update_dict(
    dict(
        path_to_weights='../../output/cheetah-stationary-target-normalizedReward-allT/2022_02_01_17_35_30',
        showcase_itr=450,
        analysis_params=dict(
            example_cases=[6, 7, 8, 9, 24, ],  # CONFIGURE! choose an array of test tasks
            multiple_episode_plots=[['time_vs_task_indicators', 'time_vs_rewards', 'time_vs_pos_const_specification'],],
        )
    ),
    cheetah_target_config
)

cheetah_target_config = prepare_variant_file(cheetah_target_config)
fig, ax = analysis(cheetah_target_config)
fig.suptitle('Target, itr. 500', size=30)
fig.tight_layout()
# Out:
# 2022-02-03 19:30:49.840620 CET | [2022_02_03_18_27_15] [2022_02_03_18_28_30] [2022_02_03_18_28_56] [2022_02_03_18_31_20] [2022_02_03_18_31_37] [2022_02_03_18_32_54] [2022_02_03_18_34_24] [2022_02_03_18_34_35] [2022_02_03_18_34_45] [2022_02_03_18_35_19] [2022_02_03_18_36_39] [2022_02_03_18_37_44] [2022_02_03_18_37_51] [2022_02_03_18_38_05] [2022_02_03_18_38_20] [2022_02_03_18_40_16] [2022_02_03_18_40_53] [2022_02_03_18_42_05] [2022_02_03_18_44_45] [2022_02_03_18_44_54] [2022_02_03_18_46_48] [2022_02_03_18_47_42] [2022_02_03_18_48_07] [2022_02_03_18_48_34] [2022_02_03_18_57_41] [2022_02_03_18_59_07] [2022_02_03_19_00_22] [2022_02_03_19_00_38] [2022_02_03_19_01_40] [2022_02_03_19_02_10] [2022_02_03_19_22_10] [2022_02_03_19_23_17] [2022_02_03_19_23_22] [2022_02_03_19_23_28] [2022_02_03_19_26_04] [2022_02_03_19_26_49] [2022_02_03_19_30_46] Variant:
# 2022-02-03 19:30:49.843502 CET | [2022_02_03_18_27_15] [2022_02_03_18_28_30] [2022_02_03_18_28_56] [2022_02_03_18_31_20] [2022_02_03_18_31_37] [2022_02_03_18_32_54] [2022_02_03_18_34_24] [2022_02_03_18_34_35] [2022_02_03_18_34_45] [2022_02_03_18_35_19] [2022_02_03_18_36_39] [2022_02_03_18_37_44] [2022_02_03_18_37_51] [2022_02_03_18_38_05] [2022_02_03_18_38_20] [2022_02_03_18_40_16] [2022_02_03_18_40_53] [2022_02_03_18_42_05] [2022_02_03_18_44_45] [2022_02_03_18_44_54] [2022_02_03_18_46_48] [2022_02_03_18_47_42] [2022_02_03_18_48_07] [2022_02_03_18_48_34] [2022_02_03_18_57_41] [2022_02_03_18_59_07] [2022_02_03_19_00_22] [2022_02_03_19_00_38] [2022_02_03_19_01_40] [2022_02_03_19_02_10] [2022_02_03_19_22_10] [2022_02_03_19_23_17] [2022_02_03_19_23_22] [2022_02_03_19_23_28] [2022_02_03_19_26_04] [2022_02_03_19_26_49] [2022_02_03_19_30_46] {
#   "env_name": "cheetah-stationary-target-normalizedReward-allT",
#   "env_params": {
#     "n_train_tasks": 100,
#     "n_eval_tasks": 30,
#     "use_normalized_env": true,
#     "scripted_policy": false,
#     "use_state_decoder": true,
#     "change_mode": "location",
#     "change_point_interval": 1,
#     "negative_change_point_basis": -1000000,
#     "positive_change_point_basis": 1000000,
#     "state_reconstruction_clip": 8,
#     "task_max_velocity": 3.0,
#     "task_min_velocity": 0.0,
#     "termination_possible": false,
#     "task_max_target": 25.0,
#     "task_min_target": 5.0
#   },
#   "path_to_weights": "../../output/cheetah-stationary-target-normalizedReward-allT/2022_02_01_17_35_30",
#   "train_or_showcase": "train",
#   "showcase_itr": 450,
#   "util_params": {
#     "base_log_dir": ".temp",
#     "temp_dir": ".temp_cemrl",
#     "use_gpu": true,
#     "use_multiprocessing": false,
#     "num_workers": 8,
#     "gpu_id": 0,
#     "debug": false,
#     "debug_encoding": true,
#     "plot": false
#   },
#   "algo_params": {
#     "policy_mode": "sac_single",
#     "num_policy_nets": 1,
#     "use_relabeler": true,
#     "use_combination_trainer": false,
#     "use_data_normalization": true,
#     "use_parametrized_alpha": false,
#     "encoding_mode": "transitionSharedY",
#     "merge_mode": "add",
#     "use_fixed_seeding": true,
#     "seed": 0,
#     "batch_size_reconstruction": 256,
#     "batch_size_validation": 4096,
#     "batch_size_combination": 256,
#     "batch_size_policy": 256,
#     "batch_size_relabel": 1024,
#     "time_steps": 30,
#     "latent_size": 1,
#     "sac_layer_size": 300,
#     "max_replay_buffer_size": 10000000,
#     "sampling_mode": null,
#     "num_last_samples": 10000000,
#     "permute_samples": false,
#     "num_train_epochs": 501,
#     "snapshot_gap": 10,
#     "num_reconstruction_steps": 5000,
#     "num_policy_steps": 2000,
#     "num_train_tasks_per_episode": 20,
#     "num_transitions_initial": 0,
#     "num_transitions_per_episode": 200,
#     "num_eval_trajectories": 2,
#     "showcase_every": 0,
#     "num_showcase_deterministic": 1,
#     "num_showcase_non_deterministic": 1,
#     "max_path_length": 200,
#     "target_entropy_factor": 1.0,
#     "sac_alpha": 1.0,
#     "lr_policy": 0.0003,
#     "lr_qf": 0.0003,
#     "data_usage_reconstruction": null,
#     "data_usage_sac": null
#   },
#   "reconstruction_params": {
#     "use_state_diff": false,
#     "reconstruct_all_timesteps": true,
#     "component_constraint_learning": false,
#     "prior_mode": "fixedOnY",
#     "prior_sigma": 0.5,
#     "num_classes": 1,
#     "lr_encoder": 0.0003,
#     "lr_decoder": 0.0003,
#     "alpha_kl_z": 0.001,
#     "beta_kl_y": 0.001,
#     "net_complex_enc_dec": 10.0,
#     "factor_qf_loss": 1.0,
#     "train_val_percent": 0.8,
#     "eval_interval": 50,
#     "early_stopping_threshold": 500,
#     "temp_folder": ".temp_cemrl"
#   },
#   "save_dir": null,
#   "analysis_params": {
#     "train_example_cases": [],
#     "example_cases": [
#       6,
#       7,
#       8,
#       9,
#       24
#     ],
#     "single_episode_plots": [],
#     "multiple_episode_plots": "[['time_vs_task_indicators', 'time_vs_rewards', 'time_vs_pos_const_specification']]",
#     "save": false,
#     "manipulate_timesteps": false,
#     "manipulate_time_steps": false,
#     "manipulate_change_trigger": false,
#     "manipulate_max_path_length": false,
#     "manipulate_test_task_number": false,
#     "plot_encoding": false,
#     "log_and_plot_progress": false,
#     "visualize_run": false,
#     "show": false
#   },
#   "exp_name": "2022_02_03_19_30_49"
# }

# %% [markdown]
# # Comparison reward function

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 6))
data_base = load_progress_log('../../output/cheetah-stationary-target-normalizedReward/2022_01_27_01_29_20')
data_allT = load_progress_log('../../output/cheetah-stationary-target-normalizedReward-allT/2022_02_01_17_35_30')
data_obs = load_progress_log('../../output/cheetah-stationary-target-normalizedReward-observable-goal/2022_01_27_14_29_22')
plot_progress_curve(data_base, 'train_avg_reward', fig_ax=(fig, ax))
plot_progress_curve(data_allT, 'train_avg_reward', fig_ax=(fig, ax))
plot_progress_curve(data_obs, 'train_avg_reward', fig_ax=(fig, ax))

ax.legend(['baseline', 'allT', 'observable'])
fig.tight_layout()

# %% [markdown]
# # Twosided targets

# %%
cheetah_target_config = copy.deepcopy(base_config)
cheetah_target_config = deep_update_dict(
    dict(
        path_to_weights='../../output/cheetah-stationary-target-twosided-allT/2022_02_03_18_14_39',
        showcase_itr=500,
        analysis_params=dict(
            example_cases=[6, 7, 8, 9, 24, ],  # CONFIGURE! choose an array of test tasks
            multiple_episode_plots=[['time_vs_task_indicators', 'time_vs_rewards', 'time_vs_pos_const_specification'],],
        )
    ),
    cheetah_target_config
)

cheetah_target_config = prepare_variant_file(cheetah_target_config)
fig, ax = analysis(cheetah_target_config)
fig.suptitle('Targets on both sides, itr. 500', size=30)
fig.tight_layout()
# Out:
# 2022-02-04 08:41:50.253723 CET | [2022_02_04_08_39_39] [2022_02_04_08_39_43] Variant:
# 2022-02-04 08:41:50.254827 CET | [2022_02_04_08_39_39] [2022_02_04_08_39_43] {
#   "env_name": "cheetah-stationary-target-twosided-allT",
#   "env_params": {
#     "n_train_tasks": 100,
#     "n_eval_tasks": 30,
#     "use_normalized_env": true,
#     "scripted_policy": false,
#     "use_state_decoder": true,
#     "change_mode": "location",
#     "change_point_interval": 1,
#     "negative_change_point_basis": -1000000,
#     "positive_change_point_basis": 1000000,
#     "state_reconstruction_clip": 8,
#     "task_max_target": 25.0,
#     "task_min_target": -25.0,
#     "termination_possible": false
#   },
#   "path_to_weights": "../../output/cheetah-stationary-target-twosided-allT/2022_02_03_18_14_39",
#   "train_or_showcase": "train",
#   "showcase_itr": 500,
#   "util_params": {
#     "base_log_dir": ".temp",
#     "temp_dir": ".temp_cemrl",
#     "use_gpu": true,
#     "use_multiprocessing": false,
#     "num_workers": 8,
#     "gpu_id": 0,
#     "debug": false,
#     "debug_encoding": true,
#     "plot": false
#   },
#   "algo_params": {
#     "policy_mode": "sac_single",
#     "num_policy_nets": 1,
#     "use_relabeler": true,
#     "use_combination_trainer": false,
#     "use_data_normalization": true,
#     "use_parametrized_alpha": false,
#     "encoding_mode": "transitionSharedY",
#     "merge_mode": "add",
#     "use_fixed_seeding": true,
#     "seed": 0,
#     "batch_size_reconstruction": 256,
#     "batch_size_validation": 4096,
#     "batch_size_combination": 256,
#     "batch_size_policy": 256,
#     "batch_size_relabel": 1024,
#     "time_steps": 30,
#     "latent_size": 1,
#     "sac_layer_size": 300,
#     "max_replay_buffer_size": 10000000,
#     "sampling_mode": null,
#     "num_last_samples": 10000000,
#     "permute_samples": false,
#     "num_train_epochs": 501,
#     "snapshot_gap": 10,
#     "num_reconstruction_steps": 5000,
#     "num_policy_steps": 2000,
#     "num_train_tasks_per_episode": 20,
#     "num_transitions_initial": 0,
#     "num_transitions_per_episode": 200,
#     "num_eval_trajectories": 2,
#     "showcase_every": 0,
#     "num_showcase_deterministic": 1,
#     "num_showcase_non_deterministic": 1,
#     "max_path_length": 200,
#     "target_entropy_factor": 1.0,
#     "sac_alpha": 1.0,
#     "lr_policy": 0.0003,
#     "lr_qf": 0.0003,
#     "data_usage_reconstruction": null,
#     "data_usage_sac": null
#   },
#   "reconstruction_params": {
#     "use_state_diff": false,
#     "reconstruct_all_timesteps": true,
#     "component_constraint_learning": false,
#     "prior_mode": "fixedOnY",
#     "prior_sigma": 0.5,
#     "num_classes": 1,
#     "lr_encoder": 0.0003,
#     "lr_decoder": 0.0003,
#     "alpha_kl_z": 0.001,
#     "beta_kl_y": 0.001,
#     "net_complex_enc_dec": 10.0,
#     "factor_qf_loss": 1.0,
#     "train_val_percent": 0.8,
#     "eval_interval": 50,
#     "early_stopping_threshold": 500
#   },
#   "save_dir": null,
#   "analysis_params": {
#     "train_example_cases": [],
#     "example_cases": [
#       6,
#       7,
#       8,
#       9,
#       24
#     ],
#     "single_episode_plots": [],
#     "multiple_episode_plots": "[['time_vs_task_indicators', 'time_vs_rewards', 'time_vs_pos_const_specification']]",
#     "plot_encoding": false,
#     "log_and_plot_progress": false,
#     "save": false,
#     "show": false,
#     "manipulate_time_steps": false,
#     "manipulate_change_trigger": false,
#     "manipulate_max_path_length": false,
#     "manipulate_test_task_number": false,
#     "visualize_run": false
#   },
#   "exp_name": "2022_02_04_08_41_50"
# }
